# %%
import panel as pn

css = '''
.bk.panel-widget-box {
  background: #f0f0f0;
  border-radius: 5px;
  border: 1px black solid;
}
'''

pn.extension(raw_css=[css])

pn.Column(
    pn.widgets.FloatSlider(name='Number', margin=(10, 5, 5, 10)),
    pn.widgets.Select(name='Fruit', options=['Apple', 'Orange', 'Pear'], margin=(0, 5, 5, 10)),
    pn.widgets.Button(name='Run', margin=(5, 10, 10, 10)),

css_classes=['panel-widget-box'])
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# Column(css_classes=['panel-widget-box'])
#     [0] FloatSlider(margin=(10, 5, 5, 10), name='Number')
#     [1] Select(margin=(0, 5, 5, 10), name='Fruit', options=['Apple', 'Orange', ...], value='Apple')
#     [2] Button(margin=(5, 10, 10, 10), name='Run')
